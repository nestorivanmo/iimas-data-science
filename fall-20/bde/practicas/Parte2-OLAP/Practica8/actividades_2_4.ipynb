# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
organizacion_df = pd.read_csv('data/organizacion.csv')
geografia_df = pd.read_csv('data/geografia.csv')
cliente_df = pd.read_csv('data/cliente.csv')
producto_df = pd.read_csv('data/producto.csv')
tiempo_df = pd.read_csv('data/tiempo.csv')
hechos_df = pd.read_csv('data/hechos.csv')

# %% [markdown]
# # Actividad 2

# %%
producto_df.head()
# Out:
#    Llave_producto  Tipo_producto_id Tipo_producto_desc  producto_id  \
# 0           40001              4001           Checking          401
# 1           40002              4001           Checking          401
# 2           40003              4001           Checking          401
# 3           40004              4001           Checking          401
# 4           40005              4001           Checking          401
#
#       producto_desc  numero_cuenta  tasa_interes  saldo_minimo
# 0  Regular Checking          57750          0.04          1000
# 1  Regular Checking          18858          0.04          1000
# 2  Regular Checking          88840          0.04          1000
# 3  Regular Checking          49239          0.04          1000
# 4  Regular Checking          23774          0.04          1000

# %%
producto_df.Tipo_producto_desc.unique()
# Out:
# array(['Checking', 'Saving', 'Mortgage', 'Personal Loan'], dtype=object)

# %%
mortgage_df = producto_df[producto_df.Tipo_producto_desc == 'Mortgage']
mortgage_df.head()
# Out:
#      Llave_producto  Tipo_producto_id Tipo_producto_desc  producto_id  \
# 270           40271              4003           Mortgage          411
# 271           40272              4003           Mortgage          411
# 272           40273              4003           Mortgage          411
# 273           40274              4003           Mortgage          411
# 274           40275              4003           Mortgage          411
#
#         producto_desc  numero_cuenta  tasa_interes  saldo_minimo
# 270  30 Year Mortgage          37166          0.05             0
# 271  30 Year Mortgage          72855          0.05             0
# 272  30 Year Mortgage          18708          0.05             0
# 273  30 Year Mortgage          58696          0.05             0
# 274  30 Year Mortgage          17941          0.05             0

# %%
list(mortgage_df.saldo_minimo.unique())
# Out:
# [0]

# %%
mortgage_ids = list(mortgage_df.Llave_producto)
clientes_ids = set()
for _, row in hechos_df.iterrows():
    llave_producto = row.Llave_producto
    if llave_producto in mortgage_ids:
        clientes_ids.add(row.Llave_cliente)
print(f'Los clientes que tienen un préstamo hipotecario son los siguientes:\n{clientes_ids}')
# Out:
# Los clientes que tienen un préstamo hipotecario son los siguientes:
# {300538, 300539}

# %%
cliente_df[cliente_df.llave_cliente.isin(clientes_ids)]
# Out:
#      llave_cliente  grupo_id grupo_desc  cliente_id nombre_cliente  \
# 537         300538     30002     Family        3538        Redfern
# 538         300539     30002     Family        3539       Richards
#
#      ingreso_cliente  edad genero estadocivil
# 537            35891    63      F      Single
# 538           115961    68      M     Married

# %%
hechos_df[hechos_df.Llave_cliente.isin(clientes_ids)]
# Out:
#      Llave_org  Llave_geografia  Llave_cliente  Llave_producto Llave_tiempo  \
# 48        1003           200283         300538           40432    1/31/2018
# 49        1003           200283         300538           40432    2/28/2018
# 50        1003           200283         300538           40432    3/31/2018
# 51        1003           200283         300538           40366    1/31/2018
# 52        1003           200283         300538           40366    2/28/2018
# ..         ...              ...            ...             ...          ...
# 190       1004           200522         300539           40323    8/31/2019
# 191       1004           200522         300539           40323    9/30/2019
# 192       1004           200522         300539           40323   10/31/2019
# 193       1004           200522         300539           40323   11/30/2019
# 194       1004           200522         300539           40323   12/31/2019
#
#        saldo
# 48     10000
# 49      7000
# 50         0
# 51    125000
# 52    120000
# ..       ...
# 190  3150000
# 191  3100000
# 192  3000000
# 193  3000000
# 194  2900000
#
# [75 rows x 6 columns]

# %%
def plot_client(id_client):
    Y = list(hechos_df[hechos_df.Llave_cliente == id_client].saldo)
    plt.plot(Y)
    plt.title(f'Saldo del cliente {id_client}')
    plt.xlabel('Número de meses')
    plt.show()

# %%
plot_client(300538)

# %%
plot_client(300539)

# %% [markdown]
# # Actividad 4

# %%
interes_productos = {}
for _, row in hechos_df.iterrows():
    producto_id = row.Llave_producto
    if producto_id not in interes_productos:
        interes_productos[producto_id] = 0
    interes_productos[producto_id] += 1
print(interes_productos)
# Out:
# {40001: 24, 40028: 24, 40136: 24, 40082: 24, 40432: 3, 40366: 24, 40434: 24, 40323: 24, 40135: 24, 40433: 24}
